# %%
import pickle
from collections import defaultdict

# %%
pkl = open('worddict.pkl', 'rb')
worddict = pickle.load(pkl)
#pickle.dump(worddict, pkl, protocol=pickle.HIGHEST_PROTOCOL)
pkl.close()

# %%
worddict
# Out:
# {'round-house': {1: defaultdict(int, {'abaft': 1, 'cabinet': 1})},
#  'ravished': {1: defaultdict(int, {'Europa': 1})},
#  'Gliding': {1: defaultdict(int, {'among': 1})},
#  'runs': {1: defaultdict(int,
#               {'all': 1,
#                'and': 1,
#                'risks': 1,
#                'roaring': 1,
#                'straight': 1,
#                'to': 2,
#                'up': 1})},
#  'hooked': {1: defaultdict(int,
#               {'Roman': 1, 'bill': 1, 'fangs': 1, 'fin': 1, 'so': 1})},
#  'Seeing': {1: defaultdict(int,
#               {'a': 1,
#                'all': 1,
#                'he': 1,
#                'himself': 1,
#                'how': 1,
#                'however': 1,
#                'me': 1,
#                'now': 2})},
#  'lain': {1: defaultdict(int, {'in': 1, 'thus': 1})},
#  'near': {1: defaultdict(int,
#               {'And': 2,
#                'Boston': 1,
#                'Call': 1,
#                'Shetland': 1,
# ...
